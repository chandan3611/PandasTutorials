# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv")

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
#df.info()

# %% [markdown]
# ### Read all row and columns by setting max value for row and columns

# %%
# Read all row and columns by setting max value for row and columns
#pd.set_option('display.max_columns', 85)
#pd.set_option('display.max_rows', 85)
#df.head()

# %%
schema_df = pd.read_csv('survey_results_schema.csv')
schema_df.head()
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...

# %%
#print schema_df
#schema_df

# %% [markdown]
# # 2. DataFrame and Series - Selecting Rows and Columns

# %% [markdown]
# ### Create dataframe from dict()

# %%
people = {"first": ["Corey", "Jane", "John"],
          "last":  ["Schafer", "Doe", "Doe"],
          "email": ["CoreymSchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com"]
         }

# %%
people
# Out:
# {'first': ['Corey', 'Jane', 'John'],
#  'last': ['Schafer', 'Doe', 'Doe'],
#  'email': ['CoreymSchafer@gmail.com',
#   'JaneDoe@gmail.com',
#   'JohnDoe@gmail.com']}

# %%
people_df = pd.DataFrame(people)
people_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreymSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
#Get column
people_df['email']
# Out:
# 0    CoreymSchafer@gmail.com
# 1          JaneDoe@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %%
type(people_df['email'])
# Out:
# pandas.core.series.Series

# %%
#Get column
people_df.email
# Out:
# 0    CoreymSchafer@gmail.com
# 1          JaneDoe@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ### Access multiple columns:
#
# we need to pass columns name in list [], and a dataframe will be returned with selected columns

# %%
people_df[['last', 'email']]
# Out:
#       last                    email
# 0  Schafer  CoreymSchafer@gmail.com
# 1      Doe        JaneDoe@gmail.com
# 2      Doe        JohnDoe@gmail.com

# %%
people_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# ### Access rows

# %% [markdown]
# ### 1) iloc : Integer location, only interger values can be used to access/search/select rows and columns

# %%
# Get first row, return: a series
people_df.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreymSchafer@gmail.com
# Name: 0, dtype: object

# %%
# Get multiple rows, return: a series
people_df.iloc[[0, 1]]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreymSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com

# %% [markdown]
# #### iloc can be used to select columns also, think iloc as function with two parameters, 1st parameter is for row and 2nd parameter for column
#
# #### dataframe.iloc[ [row], [col] ]

# %%
people_df.iloc[[0,1], 2]
# Out:
# 0    CoreymSchafer@gmail.com
# 1          JaneDoe@gmail.com
# Name: email, dtype: object

# %%
# select multiple rows and columns
people_df.iloc[[0,1], [1,2]]
# Out:
#       last                    email
# 0  Schafer  CoreymSchafer@gmail.com
# 1      Doe        JaneDoe@gmail.com

# %% [markdown]
# ### 2) loc: location, with loc we will be searching/selecting by label for rows. Label for rows means indexes, if custom index is not present then this default indexes will just range of integeres

# %%
# Select first row using .loc, this case look like .iloc because custom index is not present
people_df.loc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreymSchafer@gmail.com
# Name: 0, dtype: object

# %%
# Select multiple row using .loc, this case look like .iloc because custom index is not present
people_df.loc[[0,1]]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreymSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com

# %%
# select row and column using .loc

people_df.loc[[0,1], 'email']
# Out:
# 0    CoreymSchafer@gmail.com
# 1          JaneDoe@gmail.com
# Name: email, dtype: object

# %%
# select multiple rows and columns using .loc. 
#Note order of the selected columns will be same as the order its passed and that may be different from original dataframe

people_df.loc[[0,1], ['email', 'last']]
# Out:
#                      email     last
# 0  CoreymSchafer@gmail.com  Schafer
# 1        JaneDoe@gmail.com      Doe

# %% [markdown]
# #### Get column of stack overflow data "survey_results_public.csv"

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist'].head(10)
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5    Yes
# 6     No
# 7    Yes
# 8    Yes
# 9    Yes
# Name: Hobbyist, dtype: object

# %%
#Total count
df['Hobbyist'].count()
# Out:
# 88883

# %%
# Get count of each unique value in "Hobbyist" column
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
# Select full first row
#df.loc[0]

# %%
# first row, 'Hobbyist' column value
df.loc[0, 'Hobbyist']
# Out:
# 'Yes'

# %%
# select first 3 rows and 'Hobbyist' column
df.loc[[0,1,2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %% [markdown]
# ### Slicing can be used to select multiple row and cloumns

# %% [markdown]
# #### df.loc [ row_start  :  row_end,   col_start  :  col_end ]
#         --> In .loc row_end and col_end inclusive
#
# #### df.iloc [ row_start_index  :  row_end_index,   col_start_index  :  col_end_index ]
#         --> In .iloc row_end_index and col_end_index is exclusive

# %%
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
df.iloc[0:2, 2:5]
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
#
#                                           OpenSource
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...

# %%
# Select all rows and columns using .iloc

df.iloc[:, :]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
# Select all rows and columns using .loc
df.loc[:, :]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %% [markdown]
# # 3. Indexes in Pandas

# %%
people_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreymSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %% [markdown]
# #### Set "email" as index

# %%
people_df['email']
# Out:
# 0    CoreymSchafer@gmail.com
# 1          JaneDoe@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %%
people_df.set_index(keys="email")
# Out:
#                          first     last
# email
# CoreymSchafer@gmail.com  Corey  Schafer
# JaneDoe@gmail.com         Jane      Doe
# JohnDoe@gmail.com         John      Doe

# %% [markdown]
# #### Modify original dataframe using "inplace" flag

# %%
people_df.set_index(keys="email", inplace=True)

# %%
people_df
# Out:
#                          first     last
# email
# CoreymSchafer@gmail.com  Corey  Schafer
# JaneDoe@gmail.com         Jane      Doe
# JohnDoe@gmail.com         John      Doe

# %%
people_df.index
# Out:
# Index(['CoreymSchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com'], dtype='object', name='email')

# %% [markdown]
# #### using newly assigned to access row

# %%
people_df.loc["CoreymSchafer@gmail.com"]
# Out:
# first      Corey
# last     Schafer
# Name: CoreymSchafer@gmail.com, dtype: object

# %%
people_df.loc["CoreymSchafer@gmail.com", "last"]
# Out:
# 'Schafer'

# %% [markdown]
# #### Reset index
# #### Reset index using .reset_index() method. Default integer index will is assigned and previous index will is added to dataframe as new column.
# #### Set drop = True for dropping index column

# %%
people_df.reset_index()
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   Jane      Doe
# 2        JohnDoe@gmail.com   John      Doe

# %%
people_df.reset_index(drop=True)
# Out:
#    first     last
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
people_df.reset_index(inplace=True)
people_df
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   Jane      Doe
# 2        JohnDoe@gmail.com   John      Doe

# %% [markdown]
# #### Set "Respondent" columns as index for survey_results_public.csv data

# %%
df.set_index(keys='Respondent', inplace=True)
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %% [markdown]
# #### Index can be set will reading csv

# %%
df1 = pd.read_csv("survey_results_public.csv", index_col="Respondent")
df1.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %% [markdown]
# #### Set "Columns" as index for schema_df

# %%
schema_df.set_index(keys="Column", inplace=True)

# %%
schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
schema_df.loc["Hobbyist"]
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc["MgrIdiot"]
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc["MgrIdiot", "QuestionText"]
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %% [markdown]
# #### Sort index

# %%
schema_df.sort_index(ascending=True, inplace=True)
schema_df.head()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...

# %% [markdown]
# # 4. Filtering

# %%
people_df
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   Jane      Doe
# 2        JohnDoe@gmail.com   John      Doe

# %% [markdown]
# #### Filter row with last name Doe

# %%
people_df['last'] == "Doe"
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt = (people_df['last'] == "Doe")

# %%
people_df[filt]
# Out:
#                email first last
# 1  JaneDoe@gmail.com  Jane  Doe
# 2  JohnDoe@gmail.com  John  Doe

# %%
people_df[people_df['last'] == "Doe"]
# Out:
#                email first last
# 1  JaneDoe@gmail.com  Jane  Doe
# 2  JohnDoe@gmail.com  John  Doe

# %% [markdown]
# ### .loc method can be also used to filter rows. In this case columns can also be passed to filter further. Example filter mail id with last name == "Doe"

# %%
people_df.loc[filt]
# Out:
#                email first last
# 1  JaneDoe@gmail.com  Jane  Doe
# 2  JohnDoe@gmail.com  John  Doe

# %%
people_df.loc[filt, "email"]
# Out:
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ###  And operator :&
#
# ### Or operator : |

# %%
filt =(people_df['first'] == "John") & (people_df['last'] == "Doe")

# %%
people_df[filt]
# Out:
#                email first last
# 2  JohnDoe@gmail.com  John  Doe

# %%
people_df.loc[filt, "email"]
# Out:
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
filt =(people_df['first'] == "John") | (people_df['last'] == "Schafer")

# %%
people_df[filt]
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 2        JohnDoe@gmail.com   John      Doe

# %%
people_df.loc[filt, "email"]
# Out:
# 0    CoreymSchafer@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ## ~ can be used to negate filter.
#
# ### Example: Get email id whose first name is not "John" or last name is not "Schafer"

# %%
people_df.loc[~filt, "email"]
# Out:
# 1    JaneDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ### From survey data filter row having salary more than 70000

# %%
high_salary = (df["ConvertedComp"] > 70000)

# %%
df[high_salary].head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 6                                                       Never
# 9                                  Once a month or more often
# 13          Less than once a month but more than once per ...
# 16                                                      Never
# 22                                    Less than once per year
#
#                                                    OpenSource  \
# Respondent
# ...

# %% [markdown]
# ### Select "Country", "LanguageWorkedWith", "ConvertedComp" columns if salary is more than 70000

# %%
df.loc[high_salary, ["Country", "LanguageWorkedWith", "ConvertedComp"]].head(10)
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 26           United States  Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 29           United States               Bash/Shell/PowerShell;JavaScript;SQL
# 30             Switzerland                                                NaN
# 32           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 35           United States                                HTML/CSS;JavaScript
#
#             ConvertedComp
# Respondent
# 6                366420.0
# 9                 95179.0
# ...

# %% [markdown]
# ### Select row from "Country" equal to United States, India, Canada, United Kingdom, Germany.

# %%
countries = ["United States", "India", "Canada", "United Kingdom", "Germany"]
filt = df["Country"].isin(countries)

# %%
df.loc[filt, "Country"].head(10)
# Out:
# Respondent
# 1     United Kingdom
# 4      United States
# 6             Canada
# 8              India
# 10             India
# 12            Canada
# 13     United States
# 14           Germany
# 15             India
# 16    United Kingdom
# Name: Country, dtype: object

# %% [markdown]
# ### Select row if "LanguageWorkedWith" contain python

# %%
filt = df["LanguageWorkedWith"].str.contains("Python", na=False)

# %%
df.loc[filt, "LanguageWorkedWith"].head(10)
# Out:
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8     Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 10                        C#;Go;JavaScript;Python;R;SQL
# 12     Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 18                                             Python;R
# 20    Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# Name: LanguageWorkedWith, dtype: object

# %% [markdown]
# # 5. Updating Rows and Columns - Modifying Data Within DataFrames

# %%
people_df
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   Jane      Doe
# 2        JohnDoe@gmail.com   John      Doe

# %%
people_df.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
people_df.columns = ['email', "first_name", "last_name"]
people_df.head()
# Out:
#                      email first_name last_name
# 0  CoreymSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe

# %% [markdown]
# ### upper case columns name

# %%
people_df.columns = [x.upper() for x in people_df.columns]
people_df.head()
# Out:
#                      EMAIL FIRST_NAME LAST_NAME
# 0  CoreymSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe

# %% [markdown]
# ### Replace space by "_" in column name

# %%
people_df.columns = people_df.columns.str.replace(" ", "_")
people_df.head()
# Out:
#                      EMAIL FIRST_NAME LAST_NAME
# 0  CoreymSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe

# %%
people_df.columns = [x.lower() for x in people_df.columns]
people_df.head()
# Out:
#                      email first_name last_name
# 0  CoreymSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@gmail.com       Jane       Doe
# 2        JohnDoe@gmail.com       John       Doe

# %% [markdown]
# ### Rename any specific columns using .rename() method

# %%
people_df.rename(columns={"first_name": "first", "last_name": "last"}, inplace=True)
people_df
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   Jane      Doe
# 2        JohnDoe@gmail.com   John      Doe

# %% [markdown]
# ### Update data in row: Update single value

# %%
people_df.loc[2, ['last', 'email']] = ['Smith', 'JohnSmith@gmail.com']

# %%
people_df
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   Jane      Doe
# 2      JohnSmith@gmail.com   John    Smith

# %% [markdown]
# ### Values can be updated using ".at" also

# %%
people_df.at[2, "last"] = "Doe"
people_df.at[2, "email"] = "JohnDoe@gmail.com"
people_df
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   Jane      Doe
# 2        JohnDoe@gmail.com   John      Doe

# %% [markdown]
# ### Below mentioned way in not correct way to change any value. Changes are applied on temporary table and you will also see warning. Instead we need to use .loc() or .iloc() method for updating any value

# %%
filt = (people_df['email'] == "JohnDoe@gmail.com")

# %%
people_df[filt]['last']
# Out:
# 2    Doe
# Name: last, dtype: object

# %%
people_df[filt]['last'] = "Smith"
# Out:
# C:\Users\Chandan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
people_df
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   Jane      Doe
# 2        JohnDoe@gmail.com   John      Doe

# %% [markdown]
# ### Use .loc() or .iloc() method to update value. Original dataframe is updated instead of temporary

# %%
people_df.loc[filt, 'last'] = "Smith"
people_df
# Out:
#                      email  first     last
# 0  CoreymSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   Jane      Doe
# 2        JohnDoe@gmail.com   John    Smith

# %% [markdown]
# ### Change multiple row at once

# %%
people_df['email'] = people_df['email'].str.lower()
people_df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2        johndoe@gmail.com   John    Smith

# %% [markdown]
# ### apply() method: used to apply any function on series or dataframe.
#
# #### Run apply() method on series.

# %%
people_df['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
### Update email columns using function. Use .apply() method,

# %%
def update_email(email):
    return email.upper()

# %%
people_df['email'].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@GMAIL.COM
# 2          JOHNDOE@GMAIL.COM
# Name: email, dtype: object

# %%
people_df['email'] = people_df['email'].apply(update_email)
people_df
# Out:
#                      email  first     last
# 0  COREYMSCHAFER@GMAIL.COM  Corey  Schafer
# 1        JANEDOE@GMAIL.COM   Jane      Doe
# 2        JOHNDOE@GMAIL.COM   John    Smith

# %%
people_df['email'] = people_df['email'].apply(lambda x: x.lower())
people_df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   Jane      Doe
# 2        johndoe@gmail.com   John    Smith

# %% [markdown]
# #### Run apply() method on Dataframe

# %%
people_df.apply(len,axis='rows')
# Out:
# email    3
# first    3
# last     3
# dtype: int64

# %%
people_df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
people_df.apply(pd.Series.min)
# Out:
# email    coreymschafer@gmail.com
# first                      Corey
# last                         Doe
# dtype: object

# %%
people_df.apply(lambda x: x.min())
# Out:
# email    coreymschafer@gmail.com
# first                      Corey
# last                         Doe
# dtype: object

# %% [markdown]
# ### applymap() method used to apply any function to all value in dataframe. Series does not support applymap() method.

# %%
people_df.applymap(len)
# Out:
#    email  first  last
# 0     23      5     7
# 1     17      4     3
# 2     17      4     5

# %%
people_df.applymap(str.lower)
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  corey  schafer
# 1        janedoe@gmail.com   jane      doe
# 2        johndoe@gmail.com   john    smith

# %% [markdown]
# ### map() method is used to subtituting each value in series with another value. map() method is only supported by Series, not by dataframe.
#
# #### Note that value which is not subtituted will be converted to NaN, like John is below example. Incase you dont want to convert to NaN then use replace() method instead of map() method.

# %%
people_df['first'].map({"Corey": "Chris", "Jane": "Mary"})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
people_df['first'] = people_df['first'].replace({"Corey": "Chris", "Jane": "Mary"})
people_df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Chris  Schafer
# 1        janedoe@gmail.com   Mary      Doe
# 2        johndoe@gmail.com   John    Smith

# %% [markdown]
# #### Rename "ConvertedComp" to "SalaryUSD"

# %%
df.rename(columns={"ConvertedComp": "SalaryUSD"}, inplace=True)

# %%
df['SalaryUSD'].head()
# Out:
# Respondent
# 1        NaN
# 2        NaN
# 3     8820.0
# 4    61000.0
# 5        NaN
# Name: SalaryUSD, dtype: float64

# %% [markdown]
# ### map "Yes" to True and "No" to False in Hobbyist columns

# %%
df["Hobbyist"].head()
# Out:
# Respondent
# 1    Yes
# 2     No
# 3    Yes
# 4     No
# 5    Yes
# Name: Hobbyist, dtype: object

# %%
df["Hobbyist"] = df["Hobbyist"].map({"Yes": True, "No": False})

# %%
df["Hobbyist"].head()
# Out:
# Respondent
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# Name: Hobbyist, dtype: bool

# %% [markdown]
# # 6. Add/Remove Rows and Columns From DataFrames

# %% [markdown]
# #### Add new column in dataframe

# %%
people_df
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Chris  Schafer
# 1        janedoe@gmail.com   Mary      Doe
# 2        johndoe@gmail.com   John    Smith

# %%
people_df["full_name"] = people_df['first'] + " " + people_df["last"]
people_df
# Out:
#                      email  first     last      full_name
# 0  coreymschafer@gmail.com  Chris  Schafer  Chris Schafer
# 1        janedoe@gmail.com   Mary      Doe       Mary Doe
# 2        johndoe@gmail.com   John    Smith     John Smith

# %% [markdown]
# #### Remove or drop columns from dataframe

# %%
people_df.drop(columns=['first', "last"], inplace=True)
people_df
# Out:
#                      email      full_name
# 0  coreymschafer@gmail.com  Chris Schafer
# 1        janedoe@gmail.com       Mary Doe
# 2        johndoe@gmail.com     John Smith

# %% [markdown]
# #### Split and expand full_name

# %%
people_df["full_name"].str.split(" ")
# Out:
# 0    [Chris, Schafer]
# 1         [Mary, Doe]
# 2       [John, Smith]
# Name: full_name, dtype: object

# %%
people_df["full_name"].str.split(" ", expand=True)
# Out:
#        0        1
# 0  Chris  Schafer
# 1   Mary      Doe
# 2   John    Smith

# %%
people_df[["first", "last"]] = people_df["full_name"].str.split(" ", expand=True)
people_df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe
# 2        johndoe@gmail.com     John Smith   John    Smith

# %% [markdown]
# #### Add new row in dataframe

# %% [markdown]
# #### Append single row

# %%
# Below error is seen because index is not ignored, set ignore_index=True to avoid this error
people_df.append({"first": "Tony"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-6cfbbc88705b> in <module>
#       1 # Below error is seen because index is not ignored, set ignore_index=True to avoid this error
# ----> 2 people_df.append({"first": "Tony"})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6656                 other = Series(other)
#    6657             if other.name is None and not ignore_index:
# -> 6658                 raise TypeError('Can only append a Series if ignore_index=True'
#    6659                                 ' or if the Series has a name')
#    6660
#
# TypeError: Can only append a Series if ignore_index=True or if the Series has a name

# %%
people_df.append({"first": "Tony"}, ignore_index=True)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe
# 2        johndoe@gmail.com     John Smith   John    Smith
# 3                      NaN            NaN   Tony      NaN

# %% [markdown]
# #### Add multiple row in dataframe or append two dataframes

# %%
people2 = {'first': ['Tony', 'Steve'],
           'last': ['Shark', 'Rogers'],
           'email': ['Ironman@avenge.com', 'Cap@avenge.com']}

people_df2 = pd.DataFrame(people2)

# %%
people_df2
# Out:
#    first    last               email
# 0   Tony   Shark  Ironman@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
people_df.append(people_df2, sort=False, ignore_index=True)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe
# 2        johndoe@gmail.com     John Smith   John    Smith
# 3       Ironman@avenge.com            NaN   Tony    Shark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %%
people_df = people_df.append(people_df2, sort=False, ignore_index=True)

# %%
people_df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe
# 2        johndoe@gmail.com     John Smith   John    Smith
# 3       Ironman@avenge.com            NaN   Tony    Shark
# 4           Cap@avenge.com            NaN  Steve   Rogers

# %% [markdown]
# #### Drop or remove row from dataframe

# %%
people_df.drop(index=4, inplace=True)
people_df
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1        janedoe@gmail.com       Mary Doe   Mary      Doe
# 2        johndoe@gmail.com     John Smith   John    Smith
# 3       Ironman@avenge.com            NaN   Tony    Shark

# %% [markdown]
# #### Get index

# %%
people_df[people_df['last'] == "Doe"].index
# Out:
# Int64Index([1], dtype='int64')

# %%
filt = people_df['last'] == 'Doe'
people_df.drop(index=people_df[filt].index)
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Chris Schafer  Chris  Schafer
# 2        johndoe@gmail.com     John Smith   John    Smith
# 3       Ironman@avenge.com            NaN   Tony    Shark

# %% [markdown]
# # 7.Sorting Data

# %%
people = {"first": ["Corey", "Jane", "John"],
          "last":  ["Schafer", "Doe", "Doe"],
          "email": ["CoreymSchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com"]
         }

people_df = pd.DataFrame(people)

# %%
people_df.sort_values(by='last')
# Out:
#    first     last                    email
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 0  Corey  Schafer  CoreymSchafer@gmail.com

# %% [markdown]
# #### sort in descending order

# %%
people_df.sort_values(by='last', ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreymSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %% [markdown]
# #### Sort on multiple columns

# %%
people_df.sort_values(by=['last', 'first'], ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreymSchafer@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com

# %%
people = {"first": ["Corey", "Jane", "John", "Adam"],
          "last":  ["Schafer", "Doe", "Doe", "Doe"],
          "email": ["CoreymSchafer@gmail.com", "JaneDoe@gmail.com", "JohnDoe@gmail.com", "A@email.com"]
         }

people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreymSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe              A@email.com

# %% [markdown]
# #### Sort "last" name is descending order and "first" name in ascending order. Pass list of boolean values for "ascending" parameter.

# %%
people_df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)
people_df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreymSchafer@gmail.com
# 3   Adam      Doe              A@email.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %% [markdown]
# #### Sort on "index" value

# %%
people_df.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreymSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe              A@email.com

# %% [markdown]
# #### Sort survey data based on country

# %%
df.sort_values(by="Country", inplace=True)

# %%
df[["Country", "SalaryUSD"]].head(20)
# Out:
#                 Country  SalaryUSD
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 26340       Afghanistan        NaN

# %%
df.sort_values(by=["Country", "SalaryUSD"], ascending=[True, False], inplace=True)

# %%
df[["Country", "SalaryUSD"]].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# ...

# %% [markdown]
# #### "n" largest value in series

# %%
df["SalaryUSD"].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %% [markdown]
# #### "n" largest value in dataframe

# %%
df.nlargest(10, columns="SalaryUSD")
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %% [markdown]
# #### "n" smallest value in dataframe

# %%
df.nsmallest(10, columns="SalaryUSD")
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      True
# 722                            I am a developer by profession     False
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %% [markdown]
# # 8. Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
df['SalaryUSD'].head(10)
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# 22450       7980.0
# 48436       4464.0
# 10746       3996.0
# 8149        1596.0
# 29736       1116.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
df['SalaryUSD'].mean()
# Out:
# 127110.73842323056

# %%
df.median()
# Out:
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe().T
# Out:
#                count          mean           std  min      25%      50%  \
# CompTotal    55945.0  5.519014e+11  7.331926e+13  0.0  20000.0  62000.0
# SalaryUSD    55823.0  1.271107e+05  2.841523e+05  0.0  25777.5  57287.0
# WorkWeekHrs  64503.0  4.212720e+01  3.728761e+01  1.0     40.0     40.0
# CodeRevHrs   49790.0  5.084308e+00  5.513931e+00  0.0      2.0      4.0
# Age          79210.0  3.033670e+01  9.178390e+00  1.0     24.0     29.0
#
#                    75%           max
# CompTotal    120000.00  1.000000e+16
# SalaryUSD    100000.00  2.000000e+06
# WorkWeekHrs      44.75  4.850000e+03
# CodeRevHrs        6.00  9.900000e+01
# Age              35.00  9.900000e+01

# %%
df["SalaryUSD"].count()
# Out:
# 55823

# %%
df["Hobbyist"].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
df["SocialMedia"].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df["SocialMedia"].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %% [markdown]
# #### Popular social media site in every country: use Groupby

# %%
df["Country"].value_counts().head()
# Out:
# United States     20949
# India              9061
# Germany            5866
# United Kingdom     5737
# Canada             3395
# Name: Country, dtype: int64

# %% [markdown]
# #### Apply Groupby on "Country" columns.

# %%
country_grp = df.groupby(by=["Country"])

# %%
country_grp.get_group("United States").head()
# Out:
#                                 MainBranch  Hobbyist              OpenSourcer  \
# Respondent
# 2940        I am a developer by profession      True                    Never
# 3133        I am a developer by profession      True                    Never
# 78960       I am a developer by profession      True  Less than once per year
# 3120        I am a developer by profession      True  Less than once per year
# 78853       I am a developer by profession     False  Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 2940        OSS is, on average, of HIGHER quality than pro...
# 3133        OSS is, on average, of HIGHER quality than pro...
# 78960       OSS is, on average, of HIGHER quality than pro...
# 3120        OSS is, on average, of HIGHER quality than pro...
# 78853       The quality of OSS and closed source software ...
#
#                     Employment        Country Student  \
# Respondent
# ...

# %% [markdown]
# #### Populor social media site in each country. Apply groupby on "Country" column and then count values for SocialMedia column.

# %%
country_grp["SocialMedia"].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %% [markdown]
# #### Groupby will return a series, with multiple index like "Country" and "SocialMedia". "Country" is first index and "SocialMedia" is 2nd index. Select index "India"

# %%
country_grp["SocialMedia"].value_counts().loc["India"]
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp["SocialMedia"].value_counts().loc[["India", "SocialMedia"]]
# Out:
# Country  SocialMedia
# India    WhatsApp                    2990
#          YouTube                     1820
#          LinkedIn                     955
#          Facebook                     841
#          Instagram                    822
#          Twitter                      542
#          Reddit                       473
#          I don't use social media     250
#          Snapchat                      23
#          Hello                          5
#          WeChat 微信                      5
#          VK ВКонта́кте                  4
#          Youku Tudou 优酷                 2
#          Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp["SocialMedia"].value_counts(normalize=True).loc["United States"]
# Out:
# SocialMedia
# Reddit                      0.284346
# Twitter                     0.173002
# Facebook                    0.141874
# YouTube                     0.122867
# I don't use social media    0.092338
# Instagram                   0.082410
# LinkedIn                    0.050883
# WhatsApp                    0.030380
# Snapchat                    0.016263
# WeChat 微信                   0.004639
# VK ВКонта́кте               0.000449
# Weibo 新浪微博                  0.000399
# Hello                       0.000100
# Youku Tudou 优酷              0.000050
# Name: SocialMedia, dtype: float64

# %% [markdown]
# #### Median salary of each county

# %%
country_grp["SalaryUSD"].median().head(10)
# Out:
# Country
# Afghanistan              6222.0
# Albania                 10818.0
# Algeria                  7878.0
# Andorra                160931.0
# Angola                   7764.0
# Antigua and Barbuda         NaN
# Argentina               17760.0
# Armenia                 19692.0
# Australia               79783.0
# Austria                 51559.0
# Name: SalaryUSD, dtype: float64

# %% [markdown]
# #### median salary for Germany

# %%
country_grp["SalaryUSD"].median().loc["Germany"]
# Out:
# 63016.0

# %% [markdown]
# #### Get mean and median for each country. .agg() meathod can be used to pass multiple aggregate function.

# %%
country_grp["SalaryUSD"].agg(["median", "mean"]).head(10)
# Out:
#                        median           mean
# Country
# Afghanistan            6222.0  101953.333333
# Albania               10818.0   21833.700000
# Algeria                7878.0   34924.047619
# Andorra              160931.0  160931.000000
# Angola                 7764.0    7764.000000
# Antigua and Barbuda       NaN            NaN
# Argentina             17760.0   29467.265306
# Armenia               19692.0   24691.733333
# Australia             79783.0  171541.116279
# Austria               51559.0   83955.639604

# %%
country_grp["SalaryUSD"].agg(["median", "mean"]).loc["Canada"]
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %% [markdown]
# #### Find number of people knew python and country is "India"

# %%
filt = df["Country"] == "India"
df.loc[filt]["LanguageWorkedWith"].str.contains("Python").sum()
# Out:
# 3105

# %% [markdown]
# #### If same approch is applied on groupby object then error will be encountered. Instead we need to use .apply() method

# %%
country_grp["LanguageWorkedWith"].str.contains("Python").sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-164-360dd9d0a063> in <module>
# ----> 1 country_grp["LanguageWorkedWith"].str.contains("Python").sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# ...

# %%
country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum()).head(10)
# Out:
# Country
# Afghanistan              8
# Albania                 23
# Algeria                 40
# Andorra                  0
# Angola                   2
# Antigua and Barbuda      0
# Argentina              191
# Armenia                 28
# Australia              790
# Austria                338
# Name: LanguageWorkedWith, dtype: int64

# %% [markdown]
# #### Select index "India"

# %%
country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum()).loc["India"]
# Out:
# 3105

# %% [markdown]
# #### What percentage of people from each country know python ?

# %%
country_respondents = df["Country"].value_counts()
country_respondents.head()
# Out:
# United States     20949
# India              9061
# Germany            5866
# United Kingdom     5737
# Canada             3395
# Name: Country, dtype: int64

# %%
country_uses_python = country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
country_uses_python.head()
# Out:
# Country
# Afghanistan     8
# Albania        23
# Algeria        40
# Andorra         0
# Angola          2
# Name: LanguageWorkedWith, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis="columns", sort=False)
python_df.head()
# Out:
#                 Country  LanguageWorkedWith
# United States     20949               10083
# India              9061                3105
# Germany            5866                2451
# United Kingdom     5737                2384
# Canada             3395                1558

# %%
python_df.rename(columns={"Country": "NumRespondents", "LanguageWorkedWith": "NumKnowsPython"}, inplace=True)

# %%
python_df.head()
# Out:
#                 NumRespondents  NumKnowsPython
# United States            20949           10083
# India                     9061            3105
# Germany                   5866            2451
# United Kingdom            5737            2384
# Canada                    3395            1558

# %%
python_df['PctKnowPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100

# %%
python_df.head()
# Out:
#                 NumRespondents  NumKnowsPython  PctKnowPython
# United States            20949           10083      48.131176
# India                     9061            3105      34.267741
# Germany                   5866            2451      41.783157
# United Kingdom            5737            2384      41.554820
# Canada                    3395            1558      45.891016

# %%
python_df.sort_values(by="PctKnowPython", ascending=False, inplace=True)
python_df.head(20)
# Out:
#                            NumRespondents  NumKnowsPython  PctKnowPython
# Niger                                   1               1     100.000000
# Timor-Leste                             1               1     100.000000
# Dominica                                1               1     100.000000
# Sao Tome and Principe                   1               1     100.000000
# Turkmenistan                            7               6      85.714286
# Mauritania                              7               5      71.428571
# Guinea                                  3               2      66.666667
# Guyana                                  3               2      66.666667
# Bahamas                                 3               2      66.666667
# Uganda                                 72              47      65.277778
# Iceland                                49              30      61.224490
# Haiti                                   5               3      60.000000
# ...

# %% [markdown]
# #### Select index "Japan"

# %%
python_df.loc["Japan"]
# Out:
# NumRespondents    391.000000
# NumKnowsPython    182.000000
# PctKnowPython      46.547315
# Name: Japan, dtype: float64

# %% [markdown]
# #### Another solution

# %%
PctKnowPython = country_grp['LanguageWorkedWith'].apply(lambda x: (x.str.contains('Python').sum() / x.count()) * 100)
PctKnowPython.head()
# Out:
# C:\Users\Chandan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in long_scalars
#   """Entry point for launching an IPython kernel.
# Country
# Afghanistan    20.512821
# Albania        27.710843
# Algeria        31.746032
# Andorra         0.000000
# Angola         50.000000
# Name: LanguageWorkedWith, dtype: float64

# %% [markdown]
# # 9. Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
import numpy as np
import pandas as pd

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
people
# Out:
# {'first': ['Corey', 'Jane', 'John', 'Chris', nan, None, 'NA'],
#  'last': ['Schafer', 'Doe', 'Doe', 'Schafer', nan, nan, 'Missing'],
#  'email': ['CoreyMSchafer@gmail.com',
#   'JaneDoe@email.com',
#   'JohnDoe@email.com',
#   None,
#   nan,
#   'Anonymous@email.com',
#   'NA'],
#  'age': ['33', '55', '63', '36', None, None, 'Missing']}

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# #### dropna() : Drop row with NaN value

# %%
people_df.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# #### people_df.dropna(axis="index", how="any"): This is default value of dropna() method. That is index will be dropped is any value is missing

# %%
people_df.dropna(axis="index", how="any")
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# #### people_df.dropna(axis="index", how="all"): Drop index if all value in row is missing

# %%
people_df.dropna(axis="index", how="all")
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
people_df.dropna(axis="columns", how="all")
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# #### drop missing value if only "email" is missing.
#
# #### Row will be dropped if "email" column is missing
# #### people_df.dropna(axis="index", how="all", subset=["email"]) . In this example how = "all", or how = "any" does not create any difference, since only one column "email" value will be checked.

# %%
people_df.dropna(axis="index", how="any", subset=["email"])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# #### Index will be dropped if both "last" name and "email" is missing.

# %%
people_df.dropna(axis="index", how="all", subset=["last", "email"])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# #### Index will be dropped if any of "last" name and "email" is missing.

# %%
people_df.dropna(axis="index", how="any", subset=["last", "email"])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
#### Replace NA and Missing string with NaN

# %%
people_df.replace("NA", np.nan, inplace=True)
people_df.replace("Missing", np.nan, inplace=True)
people_df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
people_df.dropna(axis="index", how="any", subset=["last", "email"])
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
people_df.dropna(axis="index", how="any")
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %% [markdown]
# #### .isna() and .fillna() method

# %%
people_df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
people_df.fillna("MISSING")
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@email.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %% [markdown]
# #### type casting

# %%
people_df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
people_df["age"] = people_df["age"].astype(float)

# %%
people_df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
people_df["age"].mean()
# Out:
# 46.75

# %% [markdown]
# #### If some custom missing value is present in .csv file like "NA" or "Missing", then we can ignore those and treat as NaN value while reading .csv file. We can simply pass list of argument that needs to be treated as NaN.

# %%
# create list value missing value that need to treated as NaN and pass as argument in read_csv
na_vals = ["NA", "Missing"]

# %%
df = pd.read_csv("survey_results_public.csv", na_values=na_vals)
schema_df = pd.read_csv('survey_results_schema.csv', na_values=na_vals)

# %%
df["YearsCode"].head()
# Out:
# 0      4
# 1    NaN
# 2      3
# 3      3
# 4     16
# Name: YearsCode, dtype: object

# %%
df["YearsCode"].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df["YearsCode"].replace("Less than 1 year", 0, inplace=True)
df["YearsCode"].replace("More than 50 years", 51, inplace=True)

# %%
df["YearsCode"].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df["YearsCode"] = df["YearsCode"].astype(float)

# %%
df["YearsCode"].mean()
# Out:
# 11.662114216834588

# %%
df["YearsCode"].median()
# Out:
# 9.0

# %% [markdown]
# # 10 Working with Dates and Time Series Data
#
# #### https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
date_df = pd.read_csv("ETH_1h.csv")

# %%
date_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
date_df.shape
# Out:
# (23674, 7)

# %%
date_df.loc[0, "Date"]
# Out:
# '2020-03-13 08-PM'

# %% [markdown]
# #### Not in datetime format

# %%
date_df.loc[0, "Date"].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-213-e9a294672c24> in <module>
# ----> 1 date_df.loc[0, "Date"].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %% [markdown]
# #### Convert in proper datetime format

# %%
date_df["Date"] = pd.to_datetime(date_df["Date"], format="%Y-%m-%d %I-%p")
date_df["Date"].head()
# Out:
# 0   2020-03-13 20:00:00
# 1   2020-03-13 19:00:00
# 2   2020-03-13 18:00:00
# 3   2020-03-13 17:00:00
# 4   2020-03-13 16:00:00
# Name: Date, dtype: datetime64[ns]

# %%
date_df.loc[0, "Date"].day_name()
# Out:
# 'Friday'

# %% [markdown]
# #### Parse date and convert "Date" column to proper datetime format while reading csv

# %%
d_parser = lambda x: pd.datetime.strptime(x, "%Y-%m-%d %I-%p")
parsed_date_df = pd.read_csv("ETH_1h.csv", parse_dates=["Date"], date_parser=d_parser)

# %%
parsed_date_df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %% [markdown]
# #### Need to use .dt class to run datetime methods on series, as shown below.

# %%
# Series will be returned.
date_df["Date"].head()
# Out:
# 0   2020-03-13 20:00:00
# 1   2020-03-13 19:00:00
# 2   2020-03-13 18:00:00
# 3   2020-03-13 17:00:00
# 4   2020-03-13 16:00:00
# Name: Date, dtype: datetime64[ns]

# %%
date_df["Date"].dt.day_name().head()
# Out:
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday
# Name: Date, dtype: object

# %%
date_df["DayOfWeek"] = date_df["Date"].dt.day_name()
date_df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#   DayOfWeek
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday

# %% [markdown]
# #### To view earliest and most recent data, we can .min() and .max() method

# %%
date_df["Date"].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
date_df["Date"].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %% [markdown]
# #### Find difference between dates

# %%
date_df["Date"].max() - date_df["Date"].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (date_df["Date"] > "2020")
date_df.loc[filt].head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#   DayOfWeek
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday

# %%
filt = (date_df["Date"] >= "2019") & (date_df["Date"] < "2020")
date_df.loc[filt].head()
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 1749 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
#
#      DayOfWeek
# 1749   Tuesday
# 1750   Tuesday
# 1751   Tuesday
# 1752   Tuesday
# 1753   Tuesday

# %%
filt = (date_df["Date"] >= pd.to_datetime("2019-01-01")) & (date_df["Date"] < pd.to_datetime("2020-01-01"))
date_df.loc[filt].head()
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 1749 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
#
#      DayOfWeek
# 1749   Tuesday
# 1750   Tuesday
# 1751   Tuesday
# 1752   Tuesday
# 1753   Tuesday

# %% [markdown]
# #### Set date as index for dataframe, after that we can use slicing for selecting row

# %%
date_df.set_index("Date", inplace=True)

# %%
date_df["2020-01" : "2020-02"].head()
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
#
#                     DayOfWeek
# Date
# 2020-02-29 23:00:00  Saturday
# 2020-02-29 22:00:00  Saturday
# 2020-02-29 21:00:00  Saturday
# 2020-02-29 20:00:00  Saturday
# 2020-02-29 19:00:00  Saturday

# %%
date_df["2020-01" : "2020-02"]["Close"].mean()
# Out:
# 195.16559027777814

# %%
date_df["2020-01-01"]["High"].max()
# Out:
# 132.68

# %% [markdown]
# #### Pandas Date Offset Codes
#
# #### https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects

# %%
highs = date_df["High"].resample("D").max()

# %%
highs["2020-01-01"]
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
highs.plot()

# %% [markdown]
# #### Resample dataframe

# %%
date_df.resample("W").mean().head()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06

# %% [markdown]
# #### Use .agg() method to apply different aggregation function on resample data

# %%
aggvalue = date_df.resample("W").agg({"Close":"mean", "High":"max", "Low":"min", "Volume":"sum"})
aggvalue.head()
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08

# %% [markdown]
# # 11. Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc

# %%
survey_df = pd.read_csv("survey_results_public.csv", index_col="Respondent")
schema_df = pd.read_csv("survey_results_schema.csv", index_col="Column")

# %%
filt = (survey_df["Country"] == "India")
India_df = survey_df[filt]
India_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %% [markdown]
# #### write to csv

# %%
India_df.to_csv("modified.csv")

# %% [markdown]
# #### write to tsv

# %%
India_df.to_csv("modified.tsv", sep="\t")

# %% [markdown]
# #### Write to xls file

# %%
India_df.to_excel("modified.xlsx")

# %% [markdown]
# #### Read from Xlsx

# %%
test_df = pd.read_excel("modified.xlsx", index_col="Respondent")

# %%
test_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %% [markdown]
# #### Write to JSON

# %%
India_df.to_json("modified.json")

# %%
India_df.to_json("modified.json", orient="records", lines=True)

# %% [markdown]
# #### Read JSON file

# %%
test_df = pd.read_json("modified.json", orient="records", lines=True)
test_df.head()
# Out:
#     Age Age1stCode BetterLife  \
# 0  24.0         16        Yes
# 1   NaN         20         No
# 2  20.0         13        Yes
# 3  23.0         15        Yes
# 4  21.0         17        Yes
#
#                                         BlockchainIs BlockchainOrg  \
# 0  Useful across many domains and could change ma...          None
# 1  Useful for immutable record keeping outside of...    Not at all
# 2                                               None          None
# 3  Useful for immutable record keeping outside of...    Not at all
# 4                                               None          None
#
#                CareerSat                                  CodeRev  CodeRevHrs  \
# 0                   None                                     None         NaN
# 1  Slightly dissatisfied  Yes, because I see value in code review         4.0
# 2                   None                                     None         NaN
# ...

# %% [markdown]
# #### Write data to SQL database

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine("postgresql://userID:userPwd@localhost:1234/sample_db")

# %%
# Create "Sample_table" and write data to the table. If table is already present then need ot set if_exists flag.
India_df.to_sql("Sample_table", engine)

# %%
# If "Sample_table" exists then replace it
India_df.to_sql("Sample_table", engine, if_exists = "replace")

# %% [markdown]
# #### Read data from SQL table

# %%
sql_df = pd.read_sql("Sample_table", engine, index_col="Respondent")

# %% [markdown]
# #### Instead of reading full table we can run SQL query to read data. Pass SQL query instead of table name

# %%
sql_df = pd.read_sql_query(sql="SELECT * FROM Sample_table", engine, index_col="Respondent")
